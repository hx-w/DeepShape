# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
import matplotlib.tri as tri

# %%
x = [0.8, 0.4, 0.5, 0.1, 0.9]
y = [0.9, 0.2, 0.5, 0.6, 0.1]
triObj = tri.Triangulation(x, y)	# 生成给定平面点组凸包的 Delauney 三角剖分.
print(triObj)
plt.triplot(triObj)	# 可以使用 triplot 函数对网格进行简单的可视化.
# Out:
# <matplotlib.tri.triangulation.Triangulation object at 0x7f3474e891e0>
# [<matplotlib.lines.Line2D at 0x7f3474e9bc40>,
#  <matplotlib.lines.Line2D at 0x7f3474e9b010>]
